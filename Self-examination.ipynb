# %%
with open('Self-examination.ipynb') as this:
    print(this.read())
# Out:
# {
#  "metadata": {
#   "name": "",
#   "signature": "sha256:493543bcda0ec2283ca5ca84667770b4764e6411ff0ee658f85cf2bb39f6078a"
#  },
#  "nbformat": 3,
#  "nbformat_minor": 0,
#  "worksheets": [
#   {
#    "cells": [
#     {
#      "cell_type": "code",
#      "collapsed": false,
#      "input": [
#       "with open('Self-examination.ipynb') as this:\n",
#       "    print(this.read())"
#      ],
#      "language": "python",
#      "metadata": {},
#      "outputs": [
#       {
#        "output_type": "stream",
#        "stream": "stdout",
#        "text": [
#         "{\n",
#         " \"metadata\": {\n",
#         "  \"name\": \"\",\n",
#         "  \"signature\": \"sha256:aa0b1d1116947dc4788a3698464dd62b7362ec23fc032409b8f27c2175b637e1\"\n",
#         " },\n",
#         " \"nbformat\": 3,\n",
#         " \"nbformat_minor\": 0,\n",
#         " \"worksheets\": [\n",
#         "  {\n",
#         "   \"cells\": [\n",
#         "    {\n",
#         "     \"cell_type\": \"code\",\n",
# ...
